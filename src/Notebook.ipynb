# %%
import logging
logging.basicConfig(level=logging.INFO, force=True)
logging.warning("hej")
logging.info("Hallå hallå")
log = logging.getLogger(__name__)
log.info("hej du")
# Out:
# WARNING:root:hej
# INFO:root:Hallå hallå
# INFO:__main__:hej du

# %%
import sys
print("hejsan", file=sys.stderr)
# Out:
# hejsan
